# %%
import pandas as pd
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Country Population Growth Predictions.csv", sep = ",")
df.head(10)
# Out:
#       Country  Area_km  Population  Pop_Density  Yearly_Change  \
# 0       Macao       30      649335        21645           1.39
# 1   Singapore      700     5850342         8358           0.79
# 2   Hong Kong     1050     7496981         7140           0.82
# 3     Bahrain      760     1701575         2239           3.68
# 4    Maldives      300      540544         1802           1.81
# 5   Palestine     6020     5101414          847           2.41
# 6     Mayotte      375      272815          728           2.50
# 7  Bangladesh   130170   164689383         1265           1.01
# 8     Burundi    25680    11890784          463           3.12
# 9      Rwanda    24670    12952218          525           2.58
#
#    One_Year_Prediction  Density_One_Year  Ten_Year_Prediction  \
# 0               658361             21945               739593
# 1              5896560              8424              6312519
# 2              7558456              7199              8111733
# 3              1764193              2321              2327755
# 4               550328              1834               638382
# 5              5224358               868              6330855
# 6               279635               746               341019
# 7            166352746              1278            181323011
# 8             12261776               477             15600709
# 9             13286385               539             16293890
#
#    Density_Ten_Year  One_Hundred_Year_Prediction  Density_One_Hundred_Year
# 0             24653                      1551911                     51730
# 1              9018                     10472112                     14960
# 2              7725                     13644505                     12995
# 3              3063                      7963371                     10478
# 4              2128                      1518929                      5063
# 5              1052                     17395822                      2890
# 6               909                       954853                      2546
# 7              1393                    331025660                      2543
# 8               608                     48990030                      1908
# 9               660                     46368940                      1880

# %%
df.shape
# Out:
# (201, 11)

# %%
total = df.isnull().sum().sort_values(ascending=False)
total
# Out:
# Country                        0
# Area_km                        0
# Population                     0
# Pop_Density                    0
# Yearly_Change                  0
# One_Year_Prediction            0
# Density_One_Year               0
# Ten_Year_Prediction            0
# Density_Ten_Year               0
# One_Hundred_Year_Prediction    0
# Density_One_Hundred_Year       0
# dtype: int64

# %%
df.head(10).transpose()
# Out:
#                                    0          1          2        3         4  \
# Country                        Macao  Singapore  Hong Kong  Bahrain  Maldives
# Area_km                           30        700       1050      760       300
# Population                    649335    5850342    7496981  1701575    540544
# Pop_Density                    21645       8358       7140     2239      1802
# Yearly_Change                   1.39       0.79       0.82     3.68      1.81
# One_Year_Prediction           658361    5896560    7558456  1764193    550328
# Density_One_Year               21945       8424       7199     2321      1834
# Ten_Year_Prediction           739593    6312519    8111733  2327755    638382
# Density_Ten_Year               24653       9018       7725     3063      2128
# One_Hundred_Year_Prediction  1551911   10472112   13644505  7963371   1518929
# Density_One_Hundred_Year       51730      14960      12995    10478      5063
#
#                                      5        6           7         8  \
# Country                      Palestine  Mayotte  Bangladesh   Burundi
# Area_km                           6020      375      130170     25680
# Population                     5101414   272815   164689383  11890784
# Pop_Density                        847      728        1265       463
# Yearly_Change                     2.41      2.5        1.01      3.12
# One_Year_Prediction            5224358   279635   166352746  12261776
# Density_One_Year                   868      746        1278       477
# Ten_Year_Prediction            6330855   341019   181323011  15600709
# Density_Ten_Year                  1052      909        1393       608
# One_Hundred_Year_Prediction   17395822   954853   331025660  48990030
# Density_One_Hundred_Year          2890     2546        2543      1908
#
#                                     9
# Country                        Rwanda
# Area_km                         24670
# Population                   12952218
# Pop_Density                       525
# Yearly_Change                    2.58
# One_Year_Prediction          13286385
# Density_One_Year                  539
# Ten_Year_Prediction          16293890
# Density_Ten_Year                  660
# One_Hundred_Year_Prediction  46368940
# Density_One_Hundred_Year         1880

# %% [markdown]
# # Hitung Total Prediksi Kepadatan 1, 10, 100 tahun Negara di Asia Tenggara

# %%
# Daftar negara Asia Tenggara
southeast_Asia = ['Brunei', 'Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Vietnam']

current_densities = df.loc[df.Country.isin(southeast_Asia), 'Pop_Density'].sum()
density_1_year = df.loc[df.Country.isin(southeast_Asia), 'Density_One_Year'].sum()
density_10_year = df.loc[df.Country.isin(southeast_Asia), 'Density_Ten_Year'].sum()
density_100_year = df.loc[df.Country.isin(southeast_Asia), 'Density_One_Hundred_Year'].sum()

# %%
densities = [current_densities, density_1_year, density_10_year, density_100_year]
labels = ['current', '1 Year', '10 Years', '100 Years']
colors = ["#4c9fd1", "#3480ba", "#20609e", "#0f4c81"]

fig, ax = plt.subplots(figsize=(10, 7))
bars = ax.bar(labels, densities, color=colors)  # Simpan hasil ax.bar ke dalam variabel 'bars'
ax.set_title('Total Prediksi Kepadatan 1, 10, 100 tahun Negara di Asia Tenggara')
ax.set_ylabel('Kepadatan Populasi')

for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, yval + 1, round(yval, 2), ha='center', va='bottom')

plt.show()

# %%
labels = ['Current Density', '1 Year Density', '10 Year Density', '100 Year Density']
values = [current_densities, density_1_year, density_10_year, density_100_year]

plt.plot(labels, values, marker='o')

plt.title('Perbandingan Kepadatan Negara-negara Asia Tenggara')
plt.xlabel('Kategori Kepadatan')
plt.ylabel('Kepadatan Populasi')

plt.grid(True)
plt.show()

# %%
southeast_Asia = ['Brunei', 'Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Vietnam']
data_asean = df.loc[df['Country'].isin(southeast_Asia)]

sns.set(style="ticks", color_codes=True)
sns.pairplot(df, vars=['Pop_Density', 'Yearly_Change'], kind='scatter', plot_kws={'alpha':0.6})

plt.suptitle("Pairplot Kepadatan populasi dan Pertumbuhan Populasi Tahunan (Negara ASEAN)", y=1.02)
plt.show()

# %%
correlation_matrix = df.corr(method='pearson', numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, fmt=".2f",
            xticklabels=correlation_matrix.columns,
            yticklabels=correlation_matrix.columns)
plt.title('Correlation Matrix Heatmap')
plt.show()
